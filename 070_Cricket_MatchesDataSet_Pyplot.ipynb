# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataM = pd.read_csv('matches.csv')

# %%
dataM
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# Q: total no of matches played in Hbad

mask1 = dataM['city'] == 'Hyderabad'

# %%
dataM[mask1]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
dataM[mask1].shape[0] #49 matches played in hybad.
# Out:
# 49

# %%
mask2 = dataM['city'] == 'Chennai'

# %%
dataM[mask2].shape[0] #48 matches plyd in Chennai.
# Out:
# 48

# %%
mask3 = dataM['season'] >= 2015

# %%
dataM[mask3].shape[0] #119 matches plyaed after season 2016.
# Out:
# 119

# %%
mask3 = dataM['team1'] == 'Mumbai Indians'

# %%
mask4 = dataM['team2'] == 'Royal Challengers Bangalore'

# %%
dataM[(mask1 & mask2) & (mask3 | mask4)]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
dataM['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %% [markdown]
# ## Plotting the Data

# %%
dataM['winner'].value_counts().plot()
# Out:
# <Axes: >

# %%
dataM['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Take Horizontal using 'barh'
dataM['winner'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
dataM['winner'].value_counts().plot(kind='pie') #not suitable to represent the data
# Out:
# <Axes: ylabel='winner'>

# %%
dataM['toss_decision'].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
dataM['toss_decision'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
dataM[['toss_decision','winner']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_decision,winner'>

# %%
win_counts = dataM.groupby(['toss_decision', 'winner']).size().unstack()

# %%
# win_counts['winner'] = (win_counts[276] / 276) * 100
# win_counts['winner'] = (win_counts[363] / 363) * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 276
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dataM['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='toss_decision'>

# %%
dataM['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataM[['toss_decision','winner']].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
