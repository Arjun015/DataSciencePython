# %%
# creating two classes for SA(Saving Account) and CA(Current Account)

class Account :
    counter = 0
    def __init__(self,opening_balance=0):
        Account.counter = Account.counter + 1
        self.id = Account.counter
        self.balance = opening_balance
        
    def __str__(self):
        return f"Account number is: {self.id} and Balance is :{self.balance}"
    
    
    def deposite(self,amount):
        if amount > 0 :
            self.balance = self.balance + amount
        
    def withdrawl(self,amount):
        if amount > 0 and self.balance >= amount:
            self.balance = self.balance - amount
            #print('Insufficient balance')
        
        

class SavingAccount():
    pass

class CurrentAccount():
    pass

sa1 = SavingAccount()
ca1 = CurrentAccount()

print(sa1)
print(ca1)
# Out:
# <__main__.SavingAccount object at 0x0000018F53B18750>
# <__main__.CurrentAccount object at 0x0000018F53B18590>

# %%
# inheriting the Account class to CA class and SA class

class Account :
    counter = 0
    def __init__(self,opening_balance=0):
        Account.counter = Account.counter + 1
        self.id = Account.counter
        self.balance = opening_balance
        
    def __str__(self):
        return f"Account number is: {self.id} and Balance is :{self.balance}"
    
    
    def deposite(self,amount):
        if amount > 0 :
            self.balance = self.balance + amount
        
    def withdrawl(self,amount):
        if amount > 0 and self.balance >= amount:
            self.balance = self.balance - amount
            
        
        

class SavingAccount(Account):
    pass

class CurrentAccount(Account):
    pass

sa1 = SavingAccount()
ca1 = CurrentAccount()

print(sa1)
print(ca1)

sa1.deposite(100)
ca1.deposite(100)
print(sa1)
print(ca1)
# Out:
# Account number is: 1 and Balance is :0
# Account number is: 2 and Balance is :0
# Account number is: 1 and Balance is :100
# Account number is: 2 and Balance is :100

# %%
# adding restriction on the no of tx(transaction)
# SA to have max 5 tx limit
# CA to have max 100 tx


class Account :
    counter = 0
    def __init__(self,opening_balance=0):
        Account.counter = Account.counter + 1
        self.id = Account.counter
        self.balance = opening_balance
        self.num_tx = 0
        self.max_tx = 5
        
    def __str__(self):
        return f"Account number is: {self.id} and Balance is :{self.balance}"
    
    
    def deposite(self,amount):
        if amount > 0 and self.num_tx < self.max_tx :
            self.balance = self.balance + amount
            self.num_tx  = self.num_tx + 1
        
    def withdrawl(self,amount):
        if amount > 0 and self.balance >= amount and self.num_tx < self.max_tx:
            self.balance = self.balance - amount
            self.num_tx = self.num_tx + 1
            
        
        

class SavingAccount(Account):
    pass

class CurrentAccount(Account):
    pass

sa1 = SavingAccount()
ca1 = CurrentAccount()

print(sa1)
print(ca1)

sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)



print(sa1)

# ca1.deposite(100)
# print(sa1)
# print(ca1)
# Out:
# Account number is: 1 and Balance is :0
# Account number is: 2 and Balance is :0
# Account number is: 1 and Balance is :500

# %%
# adding restriction on the no of tx
# SA to have max 5 tx limit
# increaing the default 5 tx to 100 for thhe CA class
# CA to have max 100 tx

class Account :
    counter = 0
    def __init__(self,opening_balance=0):
        Account.counter = Account.counter + 1
        self.id = Account.counter
        self.balance = opening_balance
        self.num_tx = 0
        self.max_tx = 5
        
    def __str__(self):
        return f"Account number is: {self.id} and Balance is :{self.balance}"
    
    
    def deposite(self,amount):
        if amount > 0 and self.num_tx < self.max_tx :
            self.balance = self.balance + amount
            self.num_tx  = self.num_tx + 1
        
    def withdrawl(self,amount):
        if amount > 0 and self.balance >= amount and self.num_tx < self.max_tx:
            self.balance = self.balance - amount
            self.num_tx = self.num_tx + 1
            
        
        

class SavingAccount(Account):
    pass

class CurrentAccount(Account):
    def __init__(self):
        super().__init__()
        self.max_tx = 100    




sa1 = SavingAccount()
ca1 = CurrentAccount()

print(sa1)
print(ca1)

ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
print(ca1)
# Out:
# Account number is: 1 and Balance is :0
# Account number is: 2 and Balance is :0
# Account number is: 2 and Balance is :900

# %%
# adding restriction on the no of tx
# for SA and CA : Unlimited deposite and limited withdrawl. 

class Account :
    counter = 0
    def __init__(self,opening_balance=0):
        Account.counter = Account.counter + 1
        self.id = Account.counter
        self.balance = opening_balance
        self.num_tx = 0
        self.max_tx = 5
        
    def __str__(self):
        return f"Account number is: {self.id} and Balance is :{self.balance}"
    
    #unlimited deposite tx
    def deposite(self,amount):  
        if amount > 0  :
            self.balance = self.balance + amount
            
    # limited withdrawl tx    
    def withdrawl(self,amount):
        if amount > 0 and self.balance >= amount and self.num_tx < self.max_tx:
            self.balance = self.balance - amount
            self.num_tx = self.num_tx + 1
            
        
        

class SavingAccount(Account):
    pass

class CurrentAccount(Account):
    pass
#     def __init__(self):
#         super().__init__()
#         self.max_tx = 100    




sa1 = SavingAccount()
ca1 = CurrentAccount()



ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
ca1.deposite(100)
print(ca1)

ca1.withdrawl(100)
ca1.withdrawl(100)
ca1.withdrawl(100)
ca1.withdrawl(100)

print(ca1)


sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)
sa1.deposite(100)

sa1.withdrawl(100)
sa1.withdrawl(100)
sa1.withdrawl(100)
sa1.withdrawl(100)
sa1.withdrawl(100)
sa1.withdrawl(100)
sa1.withdrawl(100)




print(sa1)
print(ca1)
# Out:
# Account number is: 2 and Balance is :1400
# Account number is: 2 and Balance is :1000
# Account number is: 1 and Balance is :500
# Account number is: 2 and Balance is :1000
