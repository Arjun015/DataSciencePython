# %%
import numpy as np
import pandas as pd

# %%
dataM = pd.read_csv('matches.csv')

# %%
dataM
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
dataM.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
dataM.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
dataM.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
dataM.tail(10)
# Out:
#       id  season           city        date                  team1  \
# 626  627    2016         Kanpur  2016-05-19  Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21         Mumbai Indians
# 630  631    2016        Kolkata  2016-05-22  Kolkata Knight Riders
# 631  632    2016         Raipur  2016-05-22       Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24          Gujarat Lions
# 633  634    2016          Delhi  2016-05-25    Sunrisers Hyderabad
# 634  635    2016          Delhi  2016-05-27          Gujarat Lions
# 635  636    2016      Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 626                Gujarat Lions                Gujarat Lions         field
# ...

# %% [markdown]
# ## UnderStanding the fields in dataFrames

# %%
dataM.shape
# Out:
# (636, 18)

# %%
dataM.ndim
# Out:
# 2

# %%
dataM.size
# Out:
# 11448

# %%
dataM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
dataM.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
dataM.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
dataM.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
dataM.describe(include='all')
# Out:
#                 id       season    city        date           team1  \
# count   636.000000   636.000000     629         636             636
# unique         NaN          NaN      30         450              14
# top            NaN          NaN  Mumbai  2012-04-19  Mumbai Indians
# freq           NaN          NaN      85           2              82
# mean    318.500000  2012.490566     NaN         NaN             NaN
# std     183.741666     2.773026     NaN         NaN             NaN
# min       1.000000  2008.000000     NaN         NaN             NaN
# 25%     159.750000  2010.000000     NaN         NaN             NaN
# 50%     318.500000  2012.000000     NaN         NaN             NaN
# 75%     477.250000  2015.000000     NaN         NaN             NaN
# max     636.000000  2017.000000     NaN         NaN             NaN
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# ...

# %%
dataM.describe(include='object')
# Out:
#           city        date           team1             team2     toss_winner  \
# count      629         636             636               636             636
# unique      30         450              14                14              14
# top     Mumbai  2012-04-19  Mumbai Indians  Delhi Daredevils  Mumbai Indians
# freq        85           2              82                84              85
#
#        toss_decision  result          winner player_of_match  \
# count            636     636             633             633
# unique             2       3              14             201
# top            field  normal  Mumbai Indians        CH Gayle
# freq             363     626              92              18
#
#                         venue          umpire1     umpire2
# count                     636              635         635
# unique                     35               44          45
# top     M Chinnaswamy Stadium  HDPK Dharmasena  SJA Taufel
# ...

# %% [markdown]
# ## getting row and columns

# %%
dataM
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#columns
dataM.winner #not recomended.
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
dataM['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
# getting multiple columns

dataM[['id','team1','team2','winner']]
# Out:
#       id                        team1                        team2  \
# 0      1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1      2               Mumbai Indians       Rising Pune Supergiant
# 2      3                Gujarat Lions        Kolkata Knight Riders
# 3      4       Rising Pune Supergiant              Kings XI Punjab
# 4      5  Royal Challengers Bangalore             Delhi Daredevils
# ..   ...                          ...                          ...
# 631  632             Delhi Daredevils  Royal Challengers Bangalore
# 632  633                Gujarat Lions  Royal Challengers Bangalore
# 633  634          Sunrisers Hyderabad        Kolkata Knight Riders
# 634  635                Gujarat Lions          Sunrisers Hyderabad
# 635  636          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# ...

# %%
# getting row
dataM.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
dataM.iloc[55]
# Out:
# id                                     56
# season                               2017
# city                               Mumbai
# date                           2017-05-16
# team1              Rising Pune Supergiant
# team2                      Mumbai Indians
# toss_winner                Mumbai Indians
# toss_decision                       field
# result                             normal
# dl_applied                              0
# winner             Rising Pune Supergiant
# win_by_runs                            20
# win_by_wickets                          0
# player_of_match         Washington Sundar
# venue                    Wankhede Stadium
# umpire1                            S Ravi
# umpire2                     C Shamshuddin
# umpire3                               NaN
# Name: 55, dtype: object

# %%
dataM.loc[55]
# Out:
# id                                     56
# season                               2017
# city                               Mumbai
# date                           2017-05-16
# team1              Rising Pune Supergiant
# team2                      Mumbai Indians
# toss_winner                Mumbai Indians
# toss_decision                       field
# result                             normal
# dl_applied                              0
# winner             Rising Pune Supergiant
# win_by_runs                            20
# win_by_wickets                          0
# player_of_match         Washington Sundar
# venue                    Wankhede Stadium
# umpire1                            S Ravi
# umpire2                     C Shamshuddin
# umpire3                               NaN
# Name: 55, dtype: object

# %%
# Slicing 
dataM[0:4] #default indexing is used
# Out:
#    id  season       city        date                   team1  \
# 0   1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# ...

# %%
dataM.loc[0:5,['id','team1','team2','winner','player_of_match']]
# Out:
#    id                        team1                        team2  \
# 0   1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2               Mumbai Indians       Rising Pune Supergiant
# 2   3                Gujarat Lions        Kolkata Knight Riders
# 3   4       Rising Pune Supergiant              Kings XI Punjab
# 4   5  Royal Challengers Bangalore             Delhi Daredevils
# 5   6                Gujarat Lions          Sunrisers Hyderabad
#
#                         winner player_of_match
# 0          Sunrisers Hyderabad    Yuvraj Singh
# 1       Rising Pune Supergiant       SPD Smith
# 2        Kolkata Knight Riders         CA Lynn
# 3              Kings XI Punjab      GJ Maxwell
# 4  Royal Challengers Bangalore       KM Jadhav
# 5          Sunrisers Hyderabad     Rashid Khan

# %%
dataM.loc[0:34,['id','team1','team2','winner','player_of_match','season','city']]
# Out:
#     id                        team1                        team2  \
# 0    1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1    2               Mumbai Indians       Rising Pune Supergiant
# 2    3                Gujarat Lions        Kolkata Knight Riders
# 3    4       Rising Pune Supergiant              Kings XI Punjab
# 4    5  Royal Challengers Bangalore             Delhi Daredevils
# 5    6                Gujarat Lions          Sunrisers Hyderabad
# 6    7        Kolkata Knight Riders               Mumbai Indians
# 7    8  Royal Challengers Bangalore              Kings XI Punjab
# 8    9             Delhi Daredevils       Rising Pune Supergiant
# 9   10          Sunrisers Hyderabad               Mumbai Indians
# 10  11              Kings XI Punjab        Kolkata Knight Riders
# 11  12  Royal Challengers Bangalore               Mumbai Indians
# 12  13       Rising Pune Supergiant                Gujarat Lions
# ...

# %%
dataM.iloc[0:5,['id','team1','team2','winner','player_of_match']] #iloc() requires numeric indexers
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 dataM.iloc[0:5,['id','team1','team2','winner','player_of_match']]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
dataM.loc[0:10,[2,4,5]] # required column names.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 dataM.loc[0:10,[2,4,5]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
dataM[0:635:70]
# Out:
#       id  season          city        date                  team1  \
# 0      1    2017     Hyderabad  2017-04-05    Sunrisers Hyderabad
# 70    71    2008       Chennai  2008-04-26  Kolkata Knight Riders
# 140  141    2009  Johannesburg  2009-05-02    Chennai Super Kings
# 210  211    2010       Chennai  2010-04-06    Chennai Super Kings
# 280  281    2011       Kolkata  2011-05-07    Chennai Super Kings
# 350  351    2012          Pune  2012-05-03         Mumbai Indians
# 420  421    2013        Mumbai  2013-04-29         Mumbai Indians
# 490  491    2014       Cuttack  2014-05-11        Kings XI Punjab
# 560  561    2015        Raipur  2015-05-09    Sunrisers Hyderabad
# 630  631    2016       Kolkata  2016-05-22  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 70           Chennai Super Kings        Kolkata Knight Riders           bat
# ...

# %%
dataM.iloc[0:635:50]
# Out:
#       id  season       city        date                    team1  \
# 0      1    2017  Hyderabad  2017-04-05      Sunrisers Hyderabad
# 50    51    2017      Delhi  2017-05-12         Delhi Daredevils
# 100  101    2008     Jaipur  2008-05-17         Rajasthan Royals
# 150  151    2009  Kimberley  2009-05-09          Deccan Chargers
# 200  201    2010     Mumbai  2010-03-30          Kings XI Punjab
# 250  251    2011    Kolkata  2011-04-17         Rajasthan Royals
# 300  301    2011      Delhi  2011-05-21         Delhi Daredevils
# 350  351    2012       Pune  2012-05-03           Mumbai Indians
# 400  401    2013  Bangalore  2013-04-16         Delhi Daredevils
# 450  451    2013       Pune  2013-05-19            Pune Warriors
# 500  501    2014  Ahmedabad  2014-05-19           Mumbai Indians
# 550  551    2015  Hyderabad  2015-05-02      Sunrisers Hyderabad
# 600  601    2016       Pune  2016-04-29  Rising Pune Supergiants
#
# ...

# %%
# accesing column using iloc()

dataM.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# dataM[['team1','team2','winner']]
dataM.iloc[:,[4,5,10,13]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner player_of_match
# 0            Sunrisers Hyderabad    Yuvraj Singh
# 1         Rising Pune Supergiant       SPD Smith
# 2          Kolkata Knight Riders         CA Lynn
# ...

# %%
dataM.iloc[:,[1,2,3,4,5,10,13]]
# Out:
#      season       city        date                        team1  \
# 0      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2017       Pune  2017-04-06               Mumbai Indians
# 2      2017     Rajkot  2017-04-07                Gujarat Lions
# 3      2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 631    2016     Raipur  2016-05-22             Delhi Daredevils
# 632    2016  Bangalore  2016-05-24                Gujarat Lions
# 633    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634    2016      Delhi  2016-05-27                Gujarat Lions
# 635    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                       winner player_of_match
# 0    Royal Challengers Bangalore          Sunrisers Hyderabad    Yuvraj Singh
# ...
