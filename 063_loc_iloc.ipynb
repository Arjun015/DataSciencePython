# %%
import numpy as np
import pandas as pd

# %%
dff = pd.read_csv('gapminder_full.csv')

# %%
dff
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# reading the 1st row data
# using loc
# usingng iloc

# %%
# loc
dff.loc[0] #if not given custome index then default index is always their.
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
# iloc
dff.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
#head
dff.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
# tail
dff.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
#  reading a range of rows using iloc

# %%
dff.iloc[1:23] #backend indexing start from '0', last one is not including.
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# 13      Albania  1957     1476505    Europe    59.280  1942.284244
# ...

# %%
dff.iloc[455:460]
# Out:
#      country  year  population continent  life_exp      gdp_cap
# 455  Ecuador  2007    13755680  Americas    74.994  6873.262326
# 456    Egypt  1952    22223309    Africa    41.893  1418.822445
# 457    Egypt  1957    25009741    Africa    44.444  1458.915272
# 458    Egypt  1962    28173309    Africa    46.992  1693.335853
# 459    Egypt  1967    31681188    Africa    49.293  1814.880728

# %%
dff[200:1500:100] #dff[start position: end position : Jump value]
# Out:
#                     country  year  population continent  life_exp  \
# 200            Burkina Faso  1992     8878303    Africa    50.260
# 300                Colombia  1952    12350771  Americas    50.643
# 400          Czech Republic  1972     9862158    Europe    70.290
# 500                 Eritrea  1992     3668440    Africa    49.991
# 600               Guatemala  1952     3146381  Americas    42.023
# 700                   India  1972   567000000      Asia    50.651
# 800                   Japan  1992   124329269      Asia    79.360
# 900                   Libya  1952     1019729    Africa    42.723
# 1000               Mongolia  1972     1320500      Asia    53.754
# 1100            New Zealand  1992     3437674   Oceania    76.330
# 1200                   Peru  1952     8025700  Americas    43.902
# 1300  Sao Tome and Principe  1972       76595    Africa    56.480
# 1400                Somalia  1992     6099799    Africa    39.658
#
#            gdp_cap
# 200     931.752773
# ...

# %%
dff.iloc[::250] #last one is not included.
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801    779.445314
# 250        Canada  2002    31902268  Americas    79.770  33328.965070
# 500       Eritrea  1992     3668440    Africa    49.991    582.858510
# 750       Ireland  1982     3480000    Europe    73.100  12618.321410
# 1000     Mongolia  1972     1320500      Asia    53.754   1421.741975
# 1250  Puerto Rico  1962     2448046  Americas    69.620   5108.344630
# 1500       Taiwan  1952     8550362      Asia    58.500   1206.947913

# %%
dff.loc[:1500:400]
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 0        Afghanistan  1952     8425333      Asia    28.801    779.445314
# 400   Czech Republic  1972     9862158    Europe    70.290  13108.453600
# 800            Japan  1992   124329269      Asia    79.360  26824.895110
# 1200            Peru  1952     8025700  Americas    43.902   3758.523437

# %%
dff.iloc[:1500:400]
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 0        Afghanistan  1952     8425333      Asia    28.801    779.445314
# 400   Czech Republic  1972     9862158    Europe    70.290  13108.453600
# 800            Japan  1992   124329269      Asia    79.360  26824.895110
# 1200            Peru  1952     8025700  Americas    43.902   3758.523437

# %%
# adding one row using append
# in the form of a dictionary

# %%
dff.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
dic = {'country':'india', 'year':1998, 'population':12344232, 'continent':'Asia', 'life_exp':2.444, 'gdp_cap':8.3442}

# %%
dic
# Out:
# {'country': 'india',
#  'year': 1998,
#  'population': 12344232,
#  'continent': 'Asia',
#  'life_exp': 2.444,
#  'gdp_cap': 8.3442}

# %%
dff.append(dic,ignore_index=True)# Last row is append.index position is 1704.
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17088\4236732093.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff.append(dic,ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# ...

# %%
# adding a row using iloc is not possible
# can be added using loc only 
# why

# %%
dff.iloc[1703]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
dff.iloc[1704] # not possible to adding row in iloc
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dff.iloc[1704]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
# ...

# %%
dff.loc[1704] = pd.Series(dic)

# %%
dff
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        india  1998    12344232      Asia     2.444    8.344200
#
# [1705 rows x 6 columns]

# %%
dff.loc[1705] = pd.Series(dic)

# %%
dff #using loc adding new row is possible.
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        india  1998    12344232      Asia     2.444    8.344200
# 1705        india  1998    12344232      Asia     2.444    8.344200
#
# [1706 rows x 6 columns]

# %%
#Removing the duplicated row


dff.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1705     True
# Length: 1706, dtype: bool

# %%
# Using boolean masking,get duplicated row
dff[dff.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1705   india  1998    12344232      Asia     2.444   8.3442

# %%
# drop_duplicates using keep='last'


dff.drop_duplicates(keep='last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        india  1998    12344232      Asia     2.444    8.344200
#
# [1705 rows x 6 columns]

# %%
# removing any row as per our need

dff.drop(0,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        india  1998    12344232      Asia     2.444    8.344200
# 1705        india  1998    12344232      Asia     2.444    8.344200
#
# [1705 rows x 6 columns]

# %%
dff.drop(3,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        india  1998    12344232      Asia     2.444    8.344200
# 1705        india  1998    12344232      Asia     2.444    8.344200
#
# [1705 rows x 6 columns]

# %%
dff.drop([3,4,5,6,7,8,9,10],axis=0) # drop the multiple row.
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 11    Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12        Albania  1952     1282697    Europe    55.230  1601.056136
# ...           ...   ...         ...       ...       ...          ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
# 1704        india  1998    12344232      Asia     2.444     8.344200
# 1705        india  1998    12344232      Asia     2.444     8.344200
#
# [1698 rows x 6 columns]

# %%
# drop any column.
dff.drop('country',axis=1)
# Out:
#       year  population continent  life_exp     gdp_cap
# 0     1952     8425333      Asia    28.801  779.445314
# 1     1957     9240934      Asia    30.332  820.853030
# 2     1962    10267083      Asia    31.997  853.100710
# 3     1967    11537966      Asia    34.020  836.197138
# 4     1972    13079460      Asia    36.088  739.981106
# ...    ...         ...       ...       ...         ...
# 1701  1997    11404948    Africa    46.809  792.449960
# 1702  2002    11926563    Africa    39.989  672.038623
# 1703  2007    12311143    Africa    43.487  469.709298
# 1704  1998    12344232      Asia     2.444    8.344200
# 1705  1998    12344232      Asia     2.444    8.344200
#
# [1706 rows x 5 columns]

# %%
# drop multiple column
dff.drop(['country','life_exp'],axis=1)
# Out:
#       year  population continent     gdp_cap
# 0     1952     8425333      Asia  779.445314
# 1     1957     9240934      Asia  820.853030
# 2     1962    10267083      Asia  853.100710
# 3     1967    11537966      Asia  836.197138
# 4     1972    13079460      Asia  739.981106
# ...    ...         ...       ...         ...
# 1701  1997    11404948    Africa  792.449960
# 1702  2002    11926563    Africa  672.038623
# 1703  2007    12311143    Africa  469.709298
# 1704  1998    12344232      Asia    8.344200
# 1705  1998    12344232      Asia    8.344200
#
# [1706 rows x 4 columns]

# %%
dff.drop(1704,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        india  1998    12344232      Asia     2.444    8.344200
#
# [1705 rows x 6 columns]

# %%
# Working with row and column Using 'loc' and 'iloc'.

dff.loc[0:10] # in loc last row is included.
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
dff.iloc[0:10] # in iloc last one is not included.
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
dff.iloc[:11]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
dff.iloc[0:10,0:4] #[row:column]
# Out:
#        country  year  population continent
# 0  Afghanistan  1952     8425333      Asia
# 1  Afghanistan  1957     9240934      Asia
# 2  Afghanistan  1962    10267083      Asia
# 3  Afghanistan  1967    11537966      Asia
# 4  Afghanistan  1972    13079460      Asia
# 5  Afghanistan  1977    14880372      Asia
# 6  Afghanistan  1982    12881816      Asia
# 7  Afghanistan  1987    13867957      Asia
# 8  Afghanistan  1992    16317921      Asia
# 9  Afghanistan  1997    22227415      Asia

# %%
dff.loc[0:10,'country':'population'] #using the actual column namnes in loc , last value is also included
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405

# %%
dff.loc[10:30,'country':'continent'] #using the actual column namnes in loc , last value is also included
# Out:
#         country  year  population continent
# 10  Afghanistan  2002    25268405      Asia
# 11  Afghanistan  2007    31889923      Asia
# 12      Albania  1952     1282697    Europe
# 13      Albania  1957     1476505    Europe
# 14      Albania  1962     1728137    Europe
# 15      Albania  1967     1984060    Europe
# 16      Albania  1972     2263554    Europe
# 17      Albania  1977     2509048    Europe
# 18      Albania  1982     2780097    Europe
# 19      Albania  1987     3075321    Europe
# 20      Albania  1992     3326498    Europe
# 21      Albania  1997     3428038    Europe
# 22      Albania  2002     3508512    Europe
# 23      Albania  2007     3600523    Europe
# 24      Algeria  1952     9279525    Africa
# 25      Algeria  1957    10270856    Africa
# 26      Algeria  1962    11000948    Africa
# 27      Algeria  1967    12760499    Africa
# 28      Algeria  1972    14760787    Africa
# 29      Algeria  1977    17152804    Africa
# ...

# %% [markdown]
# # Operation in Pandas

# %%
dff.describe()
# Out:
#               year    population     life_exp        gdp_cap
# count  1706.000000  1.706000e+03  1706.000000    1706.000000
# mean   1979.521688  2.958098e+07    59.407581    7206.878098
# std      17.266816  1.060973e+08    13.056289    9854.759475
# min    1952.000000  6.001100e+04     2.444000       8.344200
# 25%    1967.000000  2.795867e+06    48.135000    1198.017212
# 50%    1982.000000  7.032074e+06    60.601000    3529.585686
# 75%    1997.000000  1.956929e+07    70.842750    9322.285886
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %%
dff['life_exp'].mean()
# Out:
# 59.40758070339976

# %%
dff['life_exp'].sum()
# Out:
# 101349.33267999999

# %%
dff['life_exp'].max()
# Out:
# 82.603

# %%
dff['life_exp'].min()
# Out:
# 2.444

# %%
#to limit the accuracy in decimal
# Q.How to remove deciml point.
