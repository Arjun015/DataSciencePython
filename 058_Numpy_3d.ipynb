# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('Goal-img.jpg')

# %%
img
# Out:
# array([[[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         ...,
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173]],
#
#        [[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         ...,
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173]],
#
#        [[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         ...,
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173]],
#
#        ...,
#
#        [[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         ...,
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173]],
#
#        [[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         ...,
#         [ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173]],
#
#        [[ 68,   0, 173],
#         [ 68,   0, 173],
#         [ 68,   0, 173],
# ...

# %%
# Checking the various parameter

# ndim
img.ndim
# Out:
# 3

# %%
# shape

img.shape
# Out:
# (1440, 1920, 3)

# %%
# size

img.size
# Out:
# 8294400

# %%
# dtype
img.dtype
# Out:
# dtype('uint8')

# %%
############# To view the Saved img   ################


plt.imshow(img)

# %%
type(img) #the imge is an ndarrya , so we have all the properties of ndarray applied on the saved image
# Out:
# numpy.ndarray

# %%
# for ex:

arr1 = np.array([1,2,3,4,5,6])

# %%
arr1[0]
# Out:
# 1

# %%
arr1[2]
# Out:
# 3

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
# likethis

plt.imshow(img[0]) #row 'zero' is Reading

# %%
plt.imshow(img[:,:,:])

# %%
# Image Cropping

plt.imshow(img[0:600,:,:])

# %%
plt.imshow(img[200:1200,750:1700])

# %%
# Image Transposing : When wants transposing img ,change the axis.

plt.imshow(np.transpose(img,(0,1,2)))# By default Normal img.

# %%
plt.imshow(np.transpose(img,(1,0,2)))

# %%
plt.imshow(np.transpose(img,(0,1,2)))
