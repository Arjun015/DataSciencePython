# %%
import numpy as np
import pandas as pd

# %%
student = pd.read_csv('students.csv')
result = pd.read_csv('result.csv')

# %%
result
# Out:
#     Unnamed: 0 seating no  Percentage Result   class
# 0            1       J301          59   Pass   third
# 1            2       J302          77   Pass   first
# 2            3       J303          89   Pass   first
# 3            4       J304          18   Fail    fail
# 4            5       J305          86   Pass   first
# 5            6       J306          50   Pass   third
# 6            7       J307          80   Pass   first
# 7            8       J308          50   Pass   third
# 8            9       J309          28   Fail    fail
# 9           10       J310          92   Pass   first
# 10          11       J311          24   Fail    fail
# 11          12       J312          74   Pass  second
# 12          13       J313          42   Pass   third
# 13          14       J314          42   Pass   third
# 14          15       J315          84   Pass   first
# 15          16       J316          40   Pass   third
# 16          17       J317          50   Pass   third
# ...

# %%
student
# Out:
#     sr no Roll no         name  class
# 0       1    J301      Aaditya      8
# 1       2    J302        Aarya      8
# 2       3    J303        Abhay      8
# 3       4    J304     Abhijeet      8
# 4       5    J305   Abhinandan      8
# ..    ...     ...          ...    ...
# 95     96    J396       Ujjwal      9
# 96     97    J397         Vasu      9
# 97     98    J398        Vidit      9
# 98     99    J399        Vijay      9
# 99    100    J400      Vishvas      9
#
# [100 rows x 4 columns]

# %%
# To get information about Table
student.describe()
# Out:
#             sr no       class
# count  100.000000  100.000000
# mean    50.500000    8.700000
# std     29.011492    0.460566
# min      1.000000    8.000000
# 25%     25.750000    8.000000
# 50%     50.500000    9.000000
# 75%     75.250000    9.000000
# max    100.000000    9.000000

# %%
student.shape #(100 rows × 4 columns)
# Out:
# (100, 4)

# %%
result.shape#(20 row,5 columns)
# Out:
# (20, 5)

# %%
result.describe(include='all')
# Out:
#         Unnamed: 0 seating no  Percentage Result  class
# count     20.00000         20   20.000000     20     20
# unique         NaN         20         NaN      2      4
# top            NaN       J301         NaN   Pass  third
# freq           NaN          1         NaN     16      7
# mean      10.50000        NaN   57.900000    NaN    NaN
# std        5.91608        NaN   24.865745    NaN    NaN
# min        1.00000        NaN   18.000000    NaN    NaN
# 25%        5.75000        NaN   41.500000    NaN    NaN
# 50%       10.50000        NaN   54.500000    NaN    NaN
# 75%       15.25000        NaN   80.250000    NaN    NaN
# max       20.00000        NaN   92.000000    NaN    NaN

# %%
result.size
# Out:
# 100

# %%
student.size
# Out:
# 400

# %%
# To check if any data missing in this table.
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sr no    100 non-null    int64
#  1   Roll no  100 non-null    object
#  2   name     100 non-null    object
#  3   class    100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     int64
#  1   seating no  20 non-null     object
#  2   Percentage  20 non-null     int64
#  3   Result      20 non-null     object
#  4   class       20 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 932.0+ bytes

# %%
student.columns
# Out:
# Index(['sr no', 'Roll no', 'name', 'class'], dtype='object')

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'seating no', 'Percentage', 'Result', 'class'], dtype='object')

# %%
result.merge(student,left_on='seating no',right_on='Roll no')
# Out:
#     Unnamed: 0 seating no  Percentage Result class_x  sr no Roll no  \
# 0            1       J301          59   Pass   third      1    J301
# 1            2       J302          77   Pass   first      2    J302
# 2            3       J303          89   Pass   first      3    J303
# 3            4       J304          18   Fail    fail      4    J304
# 4            5       J305          86   Pass   first      5    J305
# 5            6       J306          50   Pass   third      6    J306
# 6            7       J307          80   Pass   first      7    J307
# 7            8       J308          50   Pass   third      8    J308
# 8            9       J309          28   Fail    fail      9    J309
# 9           10       J310          92   Pass   first     10    J310
# 10          11       J311          24   Fail    fail     11    J311
# 11          12       J312          74   Pass  second     12    J312
# 12          13       J313          42   Pass   third     13    J313
# ...

# %%
result.merge(student,left_on='seating no',right_on='Roll no',how='left') #how ='left'
# Out:
#     Unnamed: 0 seating no  Percentage Result class_x  sr no Roll no  \
# 0            1       J301          59   Pass   third      1    J301
# 1            2       J302          77   Pass   first      2    J302
# 2            3       J303          89   Pass   first      3    J303
# 3            4       J304          18   Fail    fail      4    J304
# 4            5       J305          86   Pass   first      5    J305
# 5            6       J306          50   Pass   third      6    J306
# 6            7       J307          80   Pass   first      7    J307
# 7            8       J308          50   Pass   third      8    J308
# 8            9       J309          28   Fail    fail      9    J309
# 9           10       J310          92   Pass   first     10    J310
# 10          11       J311          24   Fail    fail     11    J311
# 11          12       J312          74   Pass  second     12    J312
# 12          13       J313          42   Pass   third     13    J313
# ...

# %%
result.merge(student) #left_on and right_on parameter required.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result.merge(student)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
# ...
